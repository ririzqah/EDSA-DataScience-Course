# %% [markdown]
# # SQL for Data Science Exam: TMDb Database
# © Explore Data Science Academy

# %% [markdown]
# ## Instructions to Students
#
# This challenge is designed to determine how much you have learned so far and will test your knowledge on SQL.
#
# The answers for this challenge should be selected on Athena for each corresponding Multiple Choice Question. The questions are included in this notebook and are numbered according to the Athena questions. The options for each question have also been included.
#
# Do not add or remove cells in this notebook. Do not edit or remove the `%%sql` comment as it is required to run each cell.
#
# **_Good Luck!_**

# %% [markdown]
# ## Honour Code
#
# I RIZQAH, MENIERS, confirm - by submitting this document - that the solutions in this notebook are a result of my own work and that I abide by the EDSA honour code (https://drive.google.com/file/d/1QDCjGZJ8-FmJE3bZdIQNwnJyQKPhHZBn/view?usp=sharing).
#
# Non-compliance with the honour code constitutes a material breach of contract.

# %% [markdown]
# ## The TMDb Database
#
# In this supplementary exam, you will be exploring the [The Movie Database](https://www.themoviedb.org/) - an online movie and TV show database, which houses some of the most popular movies and TV shows at your finger tips. The TMDb database supports 39 official languages used in over 180 countries daily, and dates all the way back to 2008.
#
#
# <img src="https://github.com/Explore-AI/Pictures/blob/master/sql_tmdb.jpg?raw=true" width=80%/>
#
#
# Below is an Entity Relationship diagram(ERD) of the TMDb database:
#
# <img src="https://github.com/Explore-AI/Pictures/blob/master/TMDB_ER_diagram.png?raw=true" width=70%/>
#
# As can be seen from the ER diagram, the TMDb database consists of `12 tables` containing information about movies, cast, genre and so much more.
#
# Let's get started!

# %% [markdown]
# ## Loading the database
#
# Before you begin, you need to prepare your SQL environment.  You can do this by loading in the magic command `%load_ext sql`.
#
# ---
# *Note: Remember that you can run the following commands to install the SQL extension dependency locally:*
#
#  - `pip install sqlalchemy`
#  - `pip install ipython-sql`
#  - `pip install pymysql`
#
# Or, for running on **Google Colab**
#   - `pip install pymysql`
# ---

# %%
# %load_ext sql

# %% [markdown]
# Next, go ahead and load in your database. To do this you will need to ensure you have downloaded the `TMDB.db` sqlite file from Athena and have stored it in a known location.

# %%
# %%sql
#
# sqlite:///TMDB.db

# %% [markdown]
# If the above line didn't throw any errors, then you should be good to go! Good luck for the Exam!

# %% [markdown]
# ## Questions on SQL
#
# Use the given cell below each question to execute your SQL queries to find the correct input from the options provided. Your solution should match one of the multiple choice questions on Athena.

# %% [markdown]
# **Question 1**
#
# Who won the Oscar for “Actor in a Leading Role” in  2015 ?
#
# (Hint winner is indicated as '1.0')
#
# **Options:**
#
#   - Micheal Fassbender
#   - Natalie Portman
#   - Leonardo DiCaprio
#   - Eddie Redmayne

# %%
# %%sql
#
# SELECT *
# FROM oscars
# WHERE award = 'Actor in a Leading Role'
# AND year = 2015
# AND winner = '1.0';
# Out:
#  * sqlite:///TMDB.db
# Done.
# []

# %% [markdown]
# **Question 2**
#
# What query will produce the ten oldest movies in the database?
#
# **Options:**
#
#  - SELECT TOP(10) * FROM movies WHERE release_date ORDER BY release_date ASC
#
#  - SELECT  * FROM movies WHERE release_date IS NOT NULL ORDER BY release_date ASC LIMIT 10
#
#  - SELECT * FROM movies WHERE release_date IS NOT NULL ORDER BY release_date DESC LIMIT 10
#
#  -  SELECT * FROM movies WHERE release_date IS NULL ORDER BY release_date DESC LIMIT 10

# %%
# %%sql
#
# SELECT *
# FROM movies
# WHERE release_date IS NOT NULL
# ORDER BY release_date ASC
# LIMIT 10;
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(3059, 'Intolerance', '1916-09-04 00:00:00.000000', 385907, None, 'en', 'Intolerance', 'The story of a poor young woman, separated by prejudice from her husband and baby, is interwoven with tales of intolerance from throughout history.', 3.232447, 8394751.0, 197.0, 'Released', 'The Cruel Hand of Intolerance', 7.4, 60),
#  (3060, 'The Big Parade', '1925-11-05 00:00:00.000000', 245000, None, 'en', 'The Big Parade', "The story of an idle rich boy who joins the US Army's Rainbow Division and is sent to France to fight in World War I, becomes friends with two working class men, experiences the horrors of trench warfare, and finds love with a French girl.", 0.785744, 22000000.0, 151.0, 'Released', None, 7.0, 21),
#  (19, 'Metropolis', '1927-01-10 00:00:00.000000', 92620000, None, 'de', 'Metropolis', "In a futuristic city sharply divided between the working class and the city planners, the son of the city's mastermind falls in love with a working class prophet who predicts the coming of a savior to mediate their differences.", 32.351527, 650422.0, 153.0, 'Released', 'There can be no understanding between the hands and the brain unless the heart acts as mediator.', 8.0, 657),
#  (905, "Pandora's Box", '1929-01-30 00:00:00.000000', 0, None, 'de', 'Die Bnchse der Pandora', 'The rise and inevitable fall of an amoral but naive young woman whose insouciant eroticism inspires lust and violence in those around her.', 1.824184, 0.0, 109.0, 'Released', None, 7.6, 45),
#  (65203, 'The Broadway Melody', '1929-02-08 00:00:00.000000', 379000, None, 'en', 'The Broadway Melody', "Harriet and Queenie Mahoney, a vaudeville act, come to Broadway, where their friend Eddie Kerns needs them for his number in one of Francis Zanfield' ... (195 characters truncated) ... eenie recognizes, that she is for Jock nothing more than a toy, and it also takes a while till Harriet recognizes, that Eddie is in love with Queenie", 0.968865, 4358000.0, 100.0, 'Released', "The pulsating drama of Broadway's bared heart speaks and sings with a voice to stir your soul!", 5.0, 19),
#  (22301, "Hell's Angels", '1930-11-15 00:00:00.000000', 3950000, None, 'en', "Hell's Angels", "Two brothers attending Oxford enlist with the Royal Flying Corps when World War I breaks out. Roy and Monte Rutledge have very different personalitie ... (576 characters truncated) ... t a strategic German munitions facility is a booming success, but with a squadron of fighters bearing down on them afterwards, escape seems unlikely.", 8.484123, 8000000.0, 127.0, 'Released', "Howard Hughes' Thrilling Multi-Million Dollar Air Spectacle", 6.1, 19),
#  (22649, 'A Farewell to Arms', '1932-12-08 00:00:00.000000', 4, None, 'en', 'A Farewell to Arms', "British nurse Catherine Barkley (Helen Hayes) and American Lieutenant Frederic Henry (Gary Cooper) fall in love during the First World War in Italy.  ... (105 characters truncated) ... the war rages on. Academy Awards winner for Best Cinematography and for Best Sound, Recording. Nominated for Best Picture and for Best Art Direction.", 1.199451, 25.0, 89.0, 'Released', 'Every woman who has loved will understand', 6.2, 28),
#  (3062, '42nd Street', '1933-02-02 00:00:00.000000', 439000, None, 'en', '42nd Street', 'A producer puts on what may be his last Broadway show, and at the last moment a chorus girl has to replace the star.', 1.933366, 2281000.0, 89.0, 'Released', None, 6.1, 37),
#  (43595, 'She Done Him Wrong', '1933-02-09 00:00:00.000000', 200000, None, 'en', 'She Done Him Wrong', '"New York singer and nightclub owner Lady Lou has more men friends than you can imagine. Unfortunately one of them is a vicious criminal who\'s escap ... (52 characters truncated) ... ing she hasn\'t exactly been faithful in his absence. Help is at hand in the form of young Captain Cummings a local temperance league leader though."', 0.622752, 2200000.0, 66.0, 'Released', "Mae West gives a 'Hot Time' to the nation!", 5.1, 27),
#  (3078, 'It Happened One Night', '1934-02-22 00:00:00.000000', 325000, None, 'en', 'It Happened One Night', "Ellie Andrews has just tied the knot with society aviator King Westley when she is whisked away to her father's yacht and out of King's clutches. Ell ... (233 characters truncated) ... ts her back to her husband, or he'll blow the whistle on Ellie to her father. Either way, Peter gets what he wants... a really juicy newspaper story!", 11.871424, 4500000.0, 105.0, 'Released', 'TOGETHER... for the first time', 7.7, 275)]

# %% [markdown]
# **Question 3**
#
# How many unique awards are there in the Oscars table?
#
# **Options:**
#  - 141
#  - 53
#  - 80
#  - 114

# %%
# %%sql
#
# SELECT COUNT(DISTINCT award)
# FROM oscars;
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(114,)]

# %% [markdown]
# **Question 4**
#
# How many movies are there that contain the word “Spider” within their title?
#
# **Options:**
#  - 0
#  - 5
#  - 1
#  - 9

# %%
# %%sql
#
# SELECT COUNT(*)
# FROM movies
# WHERE title LIKE '%Spider%';
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(9,)]

# %% [markdown]
# **Question 5**
#
# How many movies are there that are both in the "Thriller" Genre and contain the keyword “love”?
#
#
# **Options:**
#  - 55
#  - 38
#  - 14
#  - 1

# %%
# %%sql
#
# SELECT COUNT(m.title)
# FROM movies AS m
#     INNER JOIN genremap AS g1
#     ON m.movie_id = g1.movie_id
#     AND m.title LIKE '%love%'
#     INNER JOIN genres AS g2
#     ON g1.genre_id = g2.genre_id
#     WHERE genre_name = 'Thriller';
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(11,)]

# %% [markdown]
# **Question 6**
#
# How many movies are there that were released between 1 August 2006 ('2006-08-01') and 1 October 2009 ('2009-10-01') that have a popularity score of more than 40 and a budget of less than 50 000 000?
#
#
# **Options:**
#
#  - 28
#  - 23
#  - 29
#  - 35

# %%
# %%sql
#
# SELECT COUNT(*)
# FROM MOVIES
# WHERE release_date BETWEEN '2006-08-01' AND '2009-10-01'
# AND popularity > 40
# AND budget < 50000000;
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(29,)]

# %% [markdown]
# **Question 7**
#
# How many unique characters has "Vin Diesel" played so far in the database?
#
# **Options:**
#  - 24
#  - 19
#  - 18
#  - 16

# %%
# %%sql
#
# SELECT COUNT(DISTINCT c.characters)
# FROM casts AS c
# WHERE c.actor_id IN (
# SELECT a.actor_id
# FROM actors AS a
# WHERE a.actor_name = 'Vin Diesel'
# );
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(16,)]

# %% [markdown]
# **Question 8**
#
# What are the Genres of the movie “The Royal Tenenbaums”?
#
#
# **Options:**
#  - Action, Romance
#  - Drama, Comedy
#  - Crime, Thriller
#  - Drama, Romance

# %%
# %%sql
#
# SELECT m.title, m.movie_id, g1.genre_id, g2.genre_name
# FROM movies AS m
#     INNER JOIN genremap AS g1
#     ON m.movie_id = g1.movie_id
#     AND m.title = 'The Royal Tenenbaums'
#     INNER JOIN genres AS g2
#     ON g1.genre_id = g2.genre_id;
# Out:
#  * sqlite:///TMDB.db
# Done.
# [('The Royal Tenenbaums', 9428, 18, 'Drama'),
#  ('The Royal Tenenbaums', 9428, 35, 'Comedy')]

# %% [markdown]
# **Question 9**
#
# What are the three production companies that have the highest movie popularity score on average, as recorded within the database?
#
#
# **Options:**
#
#  - MCL Films S.A., Turner Pictures, George Stevens Productions
#  - The Donners' Company, Bulletproof Cupid and Kinberg Genre
#  - Bulletproof Cupid, The Donners' Company, MCL Films S.A
#  - B.Sting Entertainment, Illumination Pictures, Aztec Musique

# %%
# %%sql
#
# SELECT m.popularity, p1.production_company_name, m.movie_id
# FROM productioncompanies AS p1
#     INNER JOIN productioncompanymap AS p2
#     ON p1.production_company_id = p2.production_company_id
#     INNER JOIN movies AS m
#     ON m.movie_id = p2.movie_id
# ORDER BY popularity DESC;
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(875.581305, 'Universal Pictures', 211672),
#  (875.581305, 'Illumination Entertainment', 211672),
#  (724.247784, 'Paramount Pictures', 157336),
#  (724.247784, 'Legendary Pictures', 157336),
#  (724.247784, 'Warner Bros.', 157336),
#  (724.247784, 'Syncopy', 157336),
#  (724.247784, 'Lynda Obst Productions', 157336),
#  (514.569956, 'Twentieth Century Fox Film Corporation', 293660),
#  (514.569956, 'Marvel Entertainment', 293660),
#  (514.569956, "The Donners' Company", 293660),
#  (514.569956, 'TSG Entertainment', 293660),
#  (514.569956, 'Kinberg Genre', 293660),
#  (481.098624, 'Marvel Studios', 118340),
#  (481.098624, 'Moving Picture Company (MPC)', 118340),
#  (481.098624, 'Bulletproof Cupid', 118340),
#  (481.098624, 'Revolution Sun Studios', 118340),
#  (434.278564, 'Village Roadshow Pictures', 76341),
#  (434.278564, 'Kennedy Miller Productions', 76341),
#  (434.278564, 'Warner Bros.', 76341),
#  (418.708552, 'Universal Studios', 135397),
#  (418.708552, 'Amblin Entertainment', 135397),
#  (418.708552, 'Legendary Pictures', 135397),
#  (418.708552, 'Fuji Television Network', 135397),
#  (418.708552, 'Dentsu', 135397),
#  (271.972889, 'Walt Disney Pictures', 22),
#  (271.972889, 'Jerry Bruckheimer Films', 22),
#  (243.791743, 'Ingenious Media', 119450),
#  (243.791743, 'Chernin Entertainment', 119450),
#  (243.791743, 'TSG Entertainment', 119450),
#  (206.227151, 'Lionsgate', 131631),
#  (206.227151, 'Color Force', 131631),
#  (203.73459, 'Walt Disney Pictures', 177572),
#  (203.73459, 'Walt Disney Animation Studios', 177572),
#  (202.042635, 'Paramount Pictures', 87101),
#  (202.042635, 'Annapurna Pictures', 87101),
#  (202.042635, 'Skydance Media', 87101),
#  (198.372395, 'Studio Babelsberg', 271110),
#  (198.372395, 'Marvel Studios', 271110),
#  (198.372395, 'Walt Disney Studios Motion Pictures', 271110),
#  (198.372395, 'Vita-Ray Dutch Productions (III)', 271110),
#  (198.372395, 'Deluxe Digital Studios', 271110),
#  (192.528841, 'Bold Films', 244786),
#  (192.528841, 'Blumhouse Productions', 244786),
#  (192.528841, 'Right of Way Films', 244786),
#  (187.322927, 'DC Comics', 155),
#  (187.322927, 'Legendary Pictures', 155),
#  (187.322927, 'Warner Bros.', 155),
#  (187.322927, 'DC Entertainment', 155),
#  (187.322927, 'Syncopy', 155),
#  (167.93287, 'Twentieth Century Fox Film Corporation', 286217),
#  (167.93287, 'Scott Free Productions', 286217),
#  (167.93287, 'Mid Atlantic Films', 286217),
#  (167.93287, 'International Traders', 286217),
#  (167.93287, 'TSG Entertainment', 286217),
#  (167.93287, 'Genre Films', 286217),
#  (167.58371, 'Legendary Pictures', 27205),
#  (167.58371, 'Warner Bros.', 27205),
#  (167.58371, 'Syncopy', 27205),
#  (165.125366, 'Walt Disney Pictures', 109445),
#  (165.125366, 'Walt Disney Animation Studios', 109445),
#  (155.790452, 'DC Comics', 209112),
#  (155.790452, 'Atlas Entertainment', 209112),
#  (155.790452, 'Warner Bros.', 209112),
#  (155.790452, 'DC Entertainment', 209112),
#  (155.790452, 'Cruel & Unusual Films', 209112),
#  (155.790452, 'RatPac-Dune Entertainment', 209112),
#  (150.437577, 'Ingenious Film Partners', 19995),
#  (150.437577, 'Twentieth Century Fox Film Corporation', 19995),
#  (150.437577, 'Dune Entertainment', 19995),
#  (150.437577, 'Lightstorm Entertainment', 19995),
#  (146.757391, 'Regency Enterprises', 550),
#  (146.757391, 'Fox 2000 Pictures', 550),
#  (146.757391, 'Taurus Film', 550),
#  (146.757391, 'Linson Films', 550),
#  (146.757391, 'Atman Entertainment', 550),
#  (146.757391, 'Knickerbocker Films', 550),
#  (145.847379, 'Walt Disney Pictures', 58),
#  (145.847379, 'Jerry Bruckheimer Films', 58),
#  (145.847379, 'Second Mate Productions', 58),
#  (145.364591, 'Black Bear Pictures', 205596),
#  (145.364591, 'Bristol Automotive', 205596),
#  (144.448633, 'Paramount Pictures', 24428),
#  (144.448633, 'Marvel Studios', 24428),
#  (143.659698, 'Paramount Pictures', 238),
#  (143.659698, 'Alfran Productions', 238),
#  (143.350376, 'Paramount Pictures', 98566),
#  (143.350376, 'Nickelodeon Movies', 98566),
#  (143.350376, 'Platinum Dunes', 98566),
#  (143.041543, 'Twentieth Century Fox Film Corporation', 210577),
#  (143.041543, 'Regency Enterprises', 210577),
#  (143.041543, 'New Regency Pictures', 210577),
#  (143.041543, 'Pacific Standard', 210577),
#  (143.041543, 'TSG Entertainment', 210577),
#  (143.041543, 'Artemple - Hollywood', 210577),
#  (140.849495, 'Columbia Pictures', 257344),
#  (140.849495, 'Happy Madison Productions', 257344),
#  (139.575085, 'Columbia Pictures', 228150),
#  (139.575085, 'QED International', 228150),
#  (139.575085, 'Crave Films', 228150),
#  (139.575085, 'LStar Capital', 228150),
#  (139.575085, 'Huayi Brothers Media', 228150),
#  (139.575085, 'Le Grisbi Productions', 228150),
#  (139.272042, 'Twentieth Century Fox Film Corporation', 246655),
#  (139.272042, "Donners' Company", 246655),
#  (139.272042, 'Marvel Entertainment', 246655),
#  (139.272042, 'Bad Hat Harry Productions', 246655),
#  (139.272042, 'TSG Entertainment', 246655),
#  (139.272042, 'Kinberg Genre', 246655),
#  (139.082615, 'Walt Disney Pictures', 285),
#  (139.082615, 'Jerry Bruckheimer Films', 285),
#  (139.082615, 'Second Mate Productions', 285),
#  (138.433168, 'Ingenious Film Partners', 61791),
#  (138.433168, 'Ingenious Media', 61791),
#  (138.433168, 'Twentieth Century Fox Film Corporation', 61791),
#  (138.433168, 'Dune Entertainment', 61791),
#  (138.433168, 'Dune Entertainment III', 61791),
#  (138.433168, 'Chernin Entertainment', 61791),
#  (138.433168, 'Big Screen Productions', 61791),
#  (138.133331, 'Paramount Pictures', 13),
#  (138.049577, 'WingNut Films', 120),
#  (138.049577, 'New Line Cinema', 120),
#  (138.049577, 'The Saul Zaentz Company', 120),
#  (136.886704, 'Universal Pictures', 93456),
#  (136.886704, 'Illumination Entertainment', 93456),
#  (136.747729, 'Castle Rock Entertainment', 278),
#  (135.413856, 'Walt Disney Pictures', 1865),
#  (135.413856, 'Jerry Bruckheimer Films', 1865),
#  (135.413856, 'Moving Picture Company (MPC)', 1865),
#  (134.279229, 'Marvel Studios', 99861),
#  (134.279229, 'Prime Focus', 99861),
#  (134.279229, 'Revolution Sun Studios', 99861),
#  (132.397737, '1492 Pictures', 672),
#  (132.397737, 'Heyday films', 672),
#  (132.397737, 'Warner Bros.', 672),
#  (131.815575, 'Ingenious Media', 198663),
#  (131.815575, 'Twentieth Century Fox Film Corporation', 198663),
#  (131.815575, 'Gotham Group', 198663),
#  (131.815575, 'Dayday Films', 198663),
#  (131.815575, 'Temple Hill Entertainment', 198663),
#  (131.815575, 'TSG Entertainment', 198663),
#  (130.311355, 'Walt Disney Pictures', 158852),
#  (130.311355, 'Babieka', 158852),
#  (130.311355, 'A113', 158852),
#  (128.655964, 'Walt Disney Pictures', 150540),
#  (128.655964, 'Pixar Animation Studios', 150540),
#  (127.525581, 'United Artists', 510),
#  (127.525581, 'Fantasy Films', 510),
#  (127.525581, 'Warner Bros.', 510),
#  (127.284427, 'Studio Babelsberg', 131634),
#  (127.284427, 'Lionsgate', 131634),
#  (127.284427, 'Color Force', 131634),
#  (127.084938, 'Summit Entertainment', 8966),
#  (127.084938, 'Maverick Films', 8966),
#  (127.084938, 'Imprint Entertainment', 8966),
#  (127.084938, 'Goldcrest Pictures', 8966),
#  (127.084938, 'Temple Hill Entertainment', 8966),
#  (127.084938, 'Twilight Productions', 8966),
#  (126.393695, 'Lucasfilm', 11),
#  (126.393695, 'Twentieth Century Fox Film Corporation', 11),
#  (125.114374, 'Walt Disney Pictures', 62177),
#  (125.114374, 'Pixar Animation Studios', 62177),
#  (123.630332, 'WingNut Films', 122),
#  (123.630332, 'New Line Cinema', 122),
#  (121.463076, 'Miramax Films', 680),
#  (121.463076, 'A Band Apart', 680),
#  (121.463076, 'Jersey Films', 680),
#  (120.965743, 'WingNut Films', 122917),
#  (120.965743, 'New Line Cinema', 122917),
#  (120.965743, 'Warner Bros. Pictures', 122917),
#  (120.965743, '3Foot7', 122917),
#  (120.965743, 'Metro-Goldwyn-Mayer (MGM)', 122917),
#  (120.725053, 'Marvel Studios', 1726),
#  (120.09361, 'Marvel Studios', 102899),
#  (118.968562, 'Studio Ghibli', 129),
#  (118.078691, 'Twentieth Century Fox Film Corporation', 127585),
#  (118.078691, "Donners' Company", 127585),
#  (118.078691, 'Marvel Entertainment', 127585),
#  (118.078691, 'Bad Hat Harry Productions', 127585),
#  (118.078691, 'TSG Entertainment', 127585),
#  (118.078691, 'Down Productions', 127585),
#  (118.078691, 'Revolution Sun Studios', 127585),
#  (116.840296, 'Paramount Pictures', 91314),
#  (116.840296, 'Amblin Entertainment', 91314),
#  (116.840296, 'Di Bonaventura Pictures', 91314),
#  (116.840296, 'Platinum Dunes', 91314),
#  (116.840296, 'China Movie Channel', 91314),
#  (116.840296, 'Hasbro Studios', 91314),
#  (116.840296, 'Ian Bryce Productions', 91314),
#  (116.840296, 'Revolution Sun Studios', 91314),
#  (116.700319, 'Columbia Pictures', 198184),
#  (116.700319, 'Media Rights Capital', 198184),
#  (116.700319, 'Sony Pictures Entertainment (SPE)', 198184),
#  (116.700319, 'Alpha Core', 198184),
#  (116.700319, 'Genre Films', 198184),
#  (116.700319, 'Simon Kinberg Productions', 198184),
#  (116.700319, 'LStar Capital', 198184),
#  (116.700319, 'Ollin Studio', 198184),
#  (115.699814, 'Columbia Pictures', 559),
#  (115.699814, 'Laura Ziskin Productions', 559),
#  (115.699814, 'Marvel Enterprises', 559),
#  (115.597753, 'Twentieth Century Fox Film Corporation', 181533),
#  (115.597753, '1492 Pictures', 181533),
#  (115.597753, '21 Laps Entertainment', 181533),
#  (115.597753, 'Moving Picture Company (MPC)', 181533),
#  (115.597753, 'TSG Entertainment', 181533),
#  (115.241998, 'Universal Pictures', 240832),
#  (115.241998, 'TF1 Films Production', 240832),
#  (115.241998, 'Canal+', 240832),
#  (115.241998, 'EuropaCorp', 240832),
#  (115.241998, 'CinT+', 240832),
#  (115.040024, 'DC Comics', 272),
#  (115.040024, 'Legendary Pictures', 272),
#  (115.040024, 'Warner Bros.', 272),
#  (115.040024, 'DC Entertainment', 272),
#  (115.040024, 'Syncopy', 272),
#  (115.040024, 'Patalex III Productions Limited', 272),
#  (114.522237, 'Paramount Pictures', 177677),
#  (114.522237, 'Skydance Productions', 177677),
#  (114.522237, 'China Movie Channel', 177677),
#  (114.522237, 'Bad Robot', 177677),
#  (114.522237, 'TC Productions', 177677),
#  (114.522237, 'Alibaba Pictures Group', 177677),
#  (114.522237, 'Odin', 177677),
#  (113.858273, 'Universal Pictures', 20352),
#  (113.858273, 'Illumination Entertainment', 20352),
#  (113.161483, 'Gotham Group', 294254),
#  (113.161483, 'Temple Hill Entertainment', 294254),
#  (113.161483, 'TSG Entertainment', 294254),
#  (112.31295, 'Legendary Pictures', 49026),
#  (112.31295, 'Warner Bros.', 49026),
#  (112.31295, 'DC Entertainment', 49026),
#  (112.31295, 'Syncopy', 49026),
#  (110.620647, 'Walt Disney Pictures', 102651),
#  (110.620647, 'Walt Disney Studios Motion Pictures', 102651),
#  (110.620647, 'Roth Films', 102651),
#  (110.153618, 'Warner Bros.', 49047),
#  (110.153618, 'Heyday Films', 49047),
#  (110.153618, 'Esperanto Filmoj', 49047),
#  (109.984351, '1492 Pictures', 671),
#  (109.984351, 'Warner Bros.', 671),
#  (109.984351, 'Heyday Films', 671),
#  (109.684788, 'Universal Pictures', 310),
#  (109.684788, 'Spyglass Entertainment', 310),
#  (109.684788, 'Shady Acres Entertainment', 310),
#  (109.684788, 'Pit Bull Productions', 310),
#  (109.528572, 'Columbia Pictures', 18),
#  (109.528572, 'Gaumont', 18),
#  (108.849621, 'WingNut Films', 49051),
#  (108.849621, 'New Line Cinema', 49051),
#  (108.849621, 'Warner Bros. Pictures', 49051),
#  (108.849621, 'Metro-Goldwyn-Mayer (MGM)', 49051),
#  (107.928811, 'Eon Productions', 10764),
#  (107.376788, 'Columbia Pictures', 206647),
#  (107.376788, 'Danjaq', 206647),
#  (107.376788, 'B24', 206647),
#  (107.069763, 'Summit Entertainment', 24021),
#  (107.069763, 'Maverick Films', 24021),
#  (107.069763, 'Imprint Entertainment', 24021),
#  (107.069763, 'Sunswept Entertainment', 24021),
#  (107.069763, 'Temple Hill Entertainment', 24021),
#  (106.914973, 'WingNut Films', 121),
#  (106.914973, 'New Line Cinema', 121),
#  (106.914973, 'The Saul Zaentz Company', 121),
#  (106.815545, 'Walt Disney Pictures', 585),
#  (106.815545, 'Pixar Animation Studios', 585),
#  (105.792936, 'Paramount Pictures', 240),
#  (105.792936, 'The Coppola Company', 240),
#  (104.469351, 'Universal Pictures', 424),
#  (104.469351, 'Amblin Entertainment', 424),
#  (104.309993, 'Village Roadshow Pictures', 603),
#  (104.309993, 'Groucho II Film Partnership', 603),
#  (104.309993, 'Silver Pictures', 603),
#  (104.309993, 'Warner Bros.', 603),
#  (104.121555, 'Amblin Entertainment', 607),
#  (104.121555, 'Columbia Pictures Corporation', 607),
#  (104.121555, 'Parkes+MacDonald Image Nation', 607),
#  (103.718387, 'Summit Entertainment', 262500),
#  (103.718387, 'Mandeville Films', 262500),
#  (103.718387, 'Red Wagon Entertainment', 262500),
#  (103.718387, 'NeoReel', 262500),
#  (103.698022, 'Castle Rock Entertainment', 497),
#  (103.698022, 'Darkwoods Productions', 497),
#  (103.698022, 'Warner Bros.', 497),
#  (102.322217, 'Universal Pictures', 168259),
#  (102.322217, 'Original Film', 168259),
#  (102.322217, 'Fuji Television Network', 168259),
#  (102.322217, 'Dentsu', 168259),
#  (102.322217, 'One Race Films', 168259),
#  (102.322217, 'China Film Co.', 168259),
#  (102.322217, 'QuTbec Production Services Tax Credit', 168259),
#  (102.322217, 'Media Rights Capital (MRC)', 168259),
#  (102.322217, 'Abu Dhabi Film Commission', 168259),
#  (102.322217, 'Colorado Office of Film, Television & Media', 168259),
#  (101.74155, 'Lightstorm Entertainment', 280),
#  (101.74155, 'Pacific Western', 280),
#  (101.74155, 'Canal+', 280),
#  (101.74155, 'Carolco Pictures', 280),
#  (101.74155, 'T2 Productions', 280),
#  (101.599427, 'Scott Free Productions', 147441),
#  (101.599427, 'Chernin Entertainment', 147441),
#  (101.599427, 'Babieka', 147441),
#  (101.599427, 'Volcano Films', 147441),
#  (101.250416, 'Patalex IV Productions Limited', 674),
#  (101.250416, 'Warner Bros.', 674),
#  (101.250416, 'Heyday Films', 674),
#  (101.187052, 'Walt Disney Pictures', 150689),
#  (101.187052, 'Genre Films', 150689),
#  (101.187052, 'Beagle Pug Films', 150689),
#  (101.187052, 'Allison Shearmur Productions', 150689),
#  (100.876794, 'Northern Lights Films', 270303),
#  (100.876794, 'Animal Kingdom', 270303),
#  (100.876794, 'Two Flints', 270303),
#  (100.635882, 'Regency Enterprises', 281957),
#  (100.635882, 'Appian Way', 281957),
#  (100.635882, 'CatchPlay', 281957),
#  (100.635882, 'Anonymous Content', 281957),
#  (100.635882, 'New Regency Pictures', 281957),
#  (100.635882, 'Hong Kong Alpha Motion Pictures Co.', 281957),
#  (100.635882, 'RatPac Entertainment', 281957),
#  (100.635882, 'M Productions', 281957),
#  (100.635882, 'Monarchy Enterprises S.a.r.l.', 281957),
#  (100.412364, 'New Line Cinema', 254128),
#  (100.412364, 'Village Roadshow Pictures', 254128),
#  (100.412364, 'Warner Bros.', 254128),
#  (100.412364, 'Flynn Picture Company', 254128),
#  (100.348805, 'New Line Cinema', 138832),
#  (100.348805, 'BenderSpink', 138832),
#  (100.348805, 'Heyday Films', 138832),
#  (100.348805, 'Newman/Tooley Films', 138832),
#  (100.348805, 'Vincent Newman Entertainment', 138832),
#  (100.348805, 'Slap Happy Productions (II)', 138832),
#  (100.21391, 'DreamWorks Animation', 82702),
#  (100.21391, 'Mad Hatter Entertainment', 82702),
#  (100.025899, 'Paramount Pictures', 597),
#  (100.025899, 'Twentieth Century Fox Film Corporation', 597),
#  (100.025899, 'Lightstorm Entertainment', 597),
#  (99.687084, 'Summit Entertainment', 50620),
#  (99.687084, 'Sunswept Entertainment', 50620),
#  (99.687084, 'Temple Hill Entertainment', 50620),
#  (99.561972, 'Twentieth Century Fox Film Corporation', 425),
#  (99.561972, 'Blue Sky Studios', 425),
#  (99.561972, 'Twentieth Century Fox Animation', 425),
#  (99.499595, 'Marvel Studios', 76338),
#  (99.398009, 'Legendary Pictures', 49521),
#  (99.398009, 'Warner Bros.', 49521),
#  (99.398009, 'DC Entertainment', 49521),
#  (99.398009, 'Syncopy', 49521),
#  (99.398009, 'Cruel and Unusual Films', 49521),
#  (98.885637, 'Warner Bros.', 767),
#  (98.885637, 'Heyday Films', 767),
#  (98.755657, 'Focus Features', 216015),
#  (98.755657, 'Trigger Street Productions', 216015),
#  (98.755657, 'Michael De Luca Productions', 216015),
#  (95.9229, 'Plan B Entertainment', 76203),
#  (95.9229, 'Regency Enterprises', 76203),
#  (95.9229, 'River Road Entertainment', 76203),
#  (95.9229, 'Film4', 76203),
#  (95.9229, 'New Regency Pictures', 76203),
#  (95.914473, 'Twentieth Century Fox Film Corporation', 2048),
#  (95.914473, 'Laurence Mark Productions', 2048),
#  (95.914473, 'Davis Entertainment', 2048),
#  (95.914473, 'Overbrook Entertainment', 2048),
#  (95.914473, 'Mediastream Vierte Film GmbH & Co. Vermarktungs KG', 2048),
#  (95.914473, 'Canlaws Productions', 2048),
#  (95.301296, 'DreamWorks SKG', 98),
#  (95.301296, 'Universal Pictures', 98),
#  (95.301296, 'Scott Free Productions', 98),
#  (95.301296, 'Red Wagon Entertainment', 98),
#  (95.301296, 'Mill Film', 98),
#  (95.301296, 'C & L', 98),
#  (95.301296, 'Dawliz', 98),
#  (95.130041, 'DNA Films', 264660),
#  (95.130041, 'Universal Pictures International (UPI)', 264660),
#  (95.130041, 'Film4', 264660),
#  (95.130041, 'A24', 264660),
#  (95.007934, 'Paramount Pictures', 106646),
#  (95.007934, 'Appian Way', 106646),
#  (95.007934, 'EMJAG Productions', 106646),
#  (95.007934, 'Red Granite Pictures', 106646),
#  (95.007934, 'Sikelia Productions', 106646),
#  (94.815867, 'Summit Entertainment', 18239),
#  (94.815867, 'Maverick Films', 18239),
#  (94.815867, 'Imprint Entertainment', 18239),
#  (94.815867, 'Sunswept Entertainment', 18239),
#  (94.815867, 'Temple Hill Entertainment', 18239),
#  (94.370564, 'WingNut Films', 57158),
#  (94.370564, 'New Line Cinema', 57158),
#  (94.370564, 'Warner Bros. Pictures', 57158),
#  (94.370564, 'Metro-Goldwyn-Mayer (MGM)', 57158),
#  (94.199316, 'Walt Disney Pictures', 278927),
#  (94.199316, 'Walt Disney Studios Motion Pictures', 278927),
#  (94.199316, 'Fairview Entertainment', 278927),
#  (94.199316, 'Moving Picture Company (MPC)', 278927),
#  (94.184658, 'Twentieth Century Fox Film Corporation', 348),
#  (94.184658, 'Brandywine Productions', 348),
#  (94.056131, 'Shaw Brothers', 78),
#  (94.056131, 'Warner Bros.', 78),
#  (94.056131, 'The Ladd Company', 78),
#  (93.067866, 'Paramount Pictures', 539),
#  (93.067866, 'Universal Pictures', 539),
#  (93.067866, 'Shamley Productions', 539),
#  (93.004993, 'Columbia Pictures', 37724),
#  (92.982009, 'Walt Disney Pictures', 812),
#  (92.201962, 'Pixar Animation Studios', 14160),
#  (91.332849, 'Columbia Pictures', 608),
#  (91.332849, 'Amblin Entertainment', 608),
#  (91.332849, 'Columbia Pictures Corporation', 608),
#  (91.332849, 'Parkes+MacDonald Image Nation', 608),
#  (91.285683, 'Fox Searchlight Pictures', 44214),
#  (91.285683, 'Dune Entertainment', 44214),
#  (91.285683, 'Protozoa Pictures', 44214),
#  (91.285683, 'Cross Creek Pictures', 44214),
#  (90.809408, 'Estudios Picasso', 1417),
#  (90.809408, 'Esperanto Filmoj', 1417),
#  (90.809408, 'Tequila Gang', 1417),
#  (90.457886, 'Walt Disney Pictures', 8587),
#  (90.457886, 'Walt Disney Feature Animation', 8587),
#  (90.33681, 'Universal Pictures', 49040),
#  (90.33681, 'Dentsu', 49040),
#  (90.33681, 'Relativity Media', 49040),
#  (90.33681, 'Kennedy/Marshall Company, The', 49040),
#  (90.33681, 'Captivate Entertainment', 49040),
#  (90.23792, 'DC Comics', 297761),
#  (90.23792, 'Dune Entertainment', 297761),
#  (90.23792, 'Atlas Entertainment', 297761),
#  (90.23792, 'Warner Bros.', 297761),
#  (90.23792, 'DC Entertainment', 297761),
#  (89.938296, 'Paramount Pictures', 17578),
#  (89.938296, 'Columbia Pictures', 17578),
#  (89.938296, 'WingNut Films', 17578),
#  (89.938296, 'Amblin Entertainment', 17578),
#  (89.938296, 'Nickelodeon Movies', 17578),
#  (89.938296, 'Kennedy/Marshall Company, The', 17578),
#  (89.938296, 'Hemisphere Media Capital', 17578),
#  (89.866276, 'Columbia Pictures', 1930),
#  (89.866276, 'Laura Ziskin Productions', 1930),
#  (89.866276, 'Marvel Entertainment', 1930),
#  (89.811154, 'Worldview Entertainment', 194662),
#  (89.811154, 'New Regency Pictures', 194662),
#  (89.811154, 'TSG Entertainment', 194662),
#  (89.811154, 'Le Grisbi Productions', 194662),
#  (89.811154, 'M Productions', 194662),
#  (89.270217, 'Columbia Pictures', 102382),
#  (89.270217, 'Marvel Enterprises', 102382),
#  (89.270217, 'Avi Arad Productions', 102382),
#  (89.270217, 'Matt Tolmach Productions', 102382),
#  (89.186492, 'Walt Disney Pictures', 62211),
#  (89.186492, 'Pixar Animation Studios', 62211),
#  (89.095538, 'Bold Films', 242582),
#  (89.095538, 'Sierra / Affinity', 242582),
#  (88.935165, 'Eon Productions', 36557),
#  (88.935165, 'Stillking Films', 36557),
#  (88.935165, 'Babelsberg Film', 36557),
#  (88.844777, 'Twentieth Century Fox Film Corporation', 260346),
#  (88.844777, 'M6 Films', 260346),
#  (88.844777, 'Canal+', 260346),
#  (88.844777, 'Grive Productions', 260346),
#  (88.844777, 'EuropaCorp', 260346),
#  (88.844777, 'CinT+', 260346),
#  (88.844777, 'M6', 260346),
#  (88.844777, 'TSG Entertainment', 260346),
#  (88.844777, 'Taken 3', 260346),
#  (88.496873, 'Alcon Entertainment', 146233),
#  (88.496873, 'Madhouse Entertainment', 146233),
#  (88.496873, '8:38 Productions', 146233),
#  (88.377076, 'United Artists', 429),
#  (88.377076, 'Constantin Film Produktion', 429),
#  (88.377076, 'Produzioni Europee Associati (PEA)', 429),
#  (88.377076, 'Arturo Gonzßlez Producciones Cinematogrßficas S.A.', 429),
#  (87.53437, 'Village Roadshow Pictures', 190859),
#  (87.53437, 'Malpaso Productions', 190859),
#  (87.53437, 'Warner Bros.', 190859),
#  (87.53437, 'RatPac-Dune Entertainment', 190859),
#  (87.53437, 'Mad Chance Productions', 190859),
#  (87.53437, '22 & Indiana Pictures', 190859),
#  (87.350802, 'Walt Disney Pictures', 9487),
#  (87.350802, 'Pixar Animation Studios', 9487),
#  (86.493424, 'Marvel Studios', 10195),
#  (86.476817, 'Universal Pictures', 2501),
#  (86.476817, 'Kennedy/Marshall Company, The', 2501),
#  (86.476817, 'Hypnotic', 2501),
#  (86.476817, 'Kalima Productions GmbH & Co. KG', 2501),
#  (86.476817, 'Stillking Films', 2501),
#  (86.201184, 'Stanley Kubrick Productions', 62),
#  (86.201184, 'Metro-Goldwyn-Mayer (MGM)', 62),
#  (86.105615, 'Summit Entertainment', 262504),
#  (86.105615, 'Lionsgate', 262504),
#  (86.105615, 'Mandeville Films', 262504),
#  (86.105615, 'Red Wagon Entertainment', 262504),
#  (85.688789, 'Pixar Animation Studios', 12),
#  (85.428395, 'Miramax Films', 189),
#  (85.428395, 'Troublemaker Studios', 189),
#  (85.428395, 'AR Films', 189),
#  (85.428395, 'Aldamisa Entertainment', 189),
#  (85.428395, 'Demarest Films', 189),
#  (85.428395, 'Solipsist Film', 189),
#  (85.428395, 'Residaco', 189),
#  (85.36908, 'Village Roadshow Pictures', 76757),
#  (85.36908, 'Dune Entertainment', 76757),
#  (85.36908, 'Anarchos Productions', 76757),
#  (85.36908, 'Warner Bros.', 76757),
#  (85.30318, 'New Line Cinema', 854),
#  (85.30318, 'Dark Horse Entertainment', 854),
#  (85.115058, 'Blue Sky Studios', 950),
#  (85.115058, 'Twentieth Century Fox Animation', 950),
#  (84.689648, 'DreamWorks Animation', 9502),
#  (84.630969, 'Studio Babelsberg', 752),
#  (84.630969, 'DC Comics', 752),
#  (84.630969, 'Virtual Studios', 752),
#  (84.630969, 'Anarchos Productions', 752),
#  (84.630969, 'Silver Pictures', 752),
#  (84.630969, 'Warner Bros.', 752),
#  (84.630969, 'Medienboard Berlin-Brandenburg', 752),
#  (84.630969, 'Fnnfte Babelsberg Film', 752),
#  (84.366984, 'DreamWorks Animation', 270946),
#  (83.893257, 'Twentieth Century Fox Film Corporation', 350),
#  (83.893257, 'Dune Entertainment', 350),
#  (83.893257, 'Major Studio Partners', 350),
#  (83.893257, 'Peninsula Films', 350),
#  (83.893257, 'Fox 2000 Pictures', 350),
#  (83.295796, 'StudioCanal', 225574),
#  (83.295796, 'Silver Pictures', 225574),
#  (83.295796, 'TF1 Films Production', 225574),
#  (83.295796, 'Canal+', 225574),
#  (83.295796, 'Anton Capital Entertainment (ACE)', 225574),
#  (83.295796, 'TF1', 225574),
#  (83.295796, 'LOVEFiLM International', 225574),
#  (82.975841, 'Universal Pictures', 238636),
#  (82.975841, 'Why Not Productions', 238636),
#  (82.975841, 'Platinum Dunes', 238636),
#  (82.975841, 'Blumhouse Productions', 238636),
#  (82.975841, '5150 Action', 238636),
#  (82.643036, 'Walt Disney Pictures', 920),
#  (82.643036, 'Pixar Animation Studios', 920),
#  (82.502566, 'Columbia Pictures', 557),
#  (82.502566, 'Marvel Enterprises', 557),
#  (82.21166, 'Legendary Pictures', 18785),
#  (82.21166, 'Green Hat Films', 18785),
#  (82.21166, 'Warner Bros.', 18785),
#  (82.21166, 'IFP Westcoast Erste', 18785),
#  (82.185281, 'New Line Cinema', 227159),
#  (82.185281, 'BenderSpink', 227159),
#  (82.185281, 'RatPac Entertainment', 227159),
#  (82.121691, 'Columbia Pictures', 68718),
#  (82.121691, 'The Weinstein Company', 68718),
#  (82.052056, 'Lakeshore Entertainment', 293863),
#  (82.052056, 'Sidney Kimmel Entertainment', 293863),
#  (82.052056, 'Sierra/Affinity', 293863),
#  (81.914696, 'Paramount Pictures', 11324),
#  (81.914696, 'Appian Way', 11324),
#  (81.914696, 'Phoenix Pictures', 11324),
#  (81.914696, 'Sikelia Productions', 11324),
#  (81.834855, 'Paramount Pictures', 72190),
#  (81.834855, 'GK Films', 72190),
#  (81.834855, 'Skydance Productions', 72190),
#  (81.834855, 'Hemisphere Media Capital', 72190),
#  (81.834855, 'Apparatus Productions', 72190),
#  (81.834855, 'Latina Pictures', 72190),
#  (81.834855, '2DUX¦', 72190),
#  (81.829237, 'Lakeshore Entertainment', 277),
#  (81.829237, 'Laurinfilm', 277),
#  (81.829237, 'Subterranean Productions LLC', 277),
#  (81.829237, 'Subterranean Productions UK Ltd.', 277),
#  (81.829237, 'Underworld Produktions GmbH', 277),
#  (81.781591, 'Twentieth Century Fox Film Corporation', 18360),
#  (81.781591, '1492 Pictures', 18360),
#  (81.781591, 'Dune Entertainment', 18360),
#  (81.781591, '21 Laps Entertainment', 18360),
#  (81.781591, 'Museum Canada Productions', 18360),
#  (81.781591, 'Moving Picture Company (MPC)', 18360),
#  (81.499621, 'Village Roadshow Pictures', 58574),
#  (81.499621, 'Silver Pictures', 58574),
#  (81.499621, 'Lin Pictures', 58574),
#  (81.499621, 'Warner Bros.', 58574),
#  (81.499621, 'Wigram Productions', 58574),
#  (81.487685, 'Twentieth Century Fox Film Corporation', 772),
#  (81.487685, 'Hughes Entertainment', 772),
#  (80.972475, 'Lucasfilm', 89),
#  (80.972475, 'Paramount Pictures', 89),
#  (80.879032, 'Twentieth Century Fox Film Corporation', 8681),
#  (80.879032, 'M6 Films', 8681),
#  (80.879032, 'Canal+', 8681),
#  (80.879032, 'TPS Star', 8681),
#  (80.879032, 'Grive Productions', 8681),
#  (80.879032, 'EuropaCorp', 8681),
#  (80.879032, 'M6', 8681),
#  (80.879032, 'Wintergreen Productions', 8681),
#  (80.879032, 'All Pictures Media', 8681),
#  (80.878605, 'DreamWorks SKG', 14),
#  (80.878605, 'Jinks/Cohen Company', 14),
#  (80.581367, 'Columbia Pictures Corporation', 1402),
#  (80.581367, 'Escape Artists', 1402),
#  (80.581367, 'Relativity Media', 1402),
#  (80.581367, 'Overbrook Entertainment', 1402),
#  (80.316463, 'Summit Entertainment', 157350),
#  (80.316463, 'Red Wagon Entertainment', 157350),
#  (80.171283, 'Walt Disney Productions', 408),
#  (79.922059, 'Columbia Pictures', 156022),
#  (79.922059, 'Village Roadshow Pictures', 156022),
#  (79.922059, 'Escape Artists', 156022),
#  (79.922059, 'Mace Neufeld Productions', 156022),
#  (79.922059, 'LStar Capital', 156022),
#  (79.922059, 'Lonetree Entertainment', 156022),
#  (79.754966, 'Miramax Films', 24),
#  (79.754966, 'A Band Apart', 24),
#  (79.754966, 'Super Cool ManChu', 24),
#  (79.679601, '1492 Pictures', 673),
#  (79.679601, 'Heyday films', 673),
#  (79.679601, 'Warner Bros.', 673),
#  (79.579532, 'New Line Cinema', 807),
#  (79.579532, 'Juno Pix', 807),
#  (79.579532, 'Cecchi Gori Pictures', 807),
#  (79.456485, 'Village Roadshow Pictures', 137113),
#  (79.456485, 'Warner Bros.', 137113),
#  (79.456485, 'Viz Media', 137113),
#  (79.456485, 'Province of British Columbia Production Services Tax Credit', 137113),
#  (79.456485, '3 Arts Entertainment', 137113),
#  (79.456485, 'RatPac-Dune Entertainment', 137113),
#  (78.699993, 'Hawk Films', 694),
#  (78.699993, 'Warner Bros.', 694),
#  (78.699993, 'Peregrine', 694),
#  (78.530105, 'Walt Disney Pictures', 12155),
#  (78.530105, 'Team Todd', 12155),
#  (78.530105, 'Tim Burton Productions', 12155),
#  (78.530105, 'Roth Films', 12155),
#  (78.530105, 'Zanuck Company, The', 12155),
#  (78.51783, 'Lucasfilm', 1891),
#  (78.51783, 'Twentieth Century Fox Film Corporation', 1891),
#  (78.291018, 'Paramount Pictures', 54138),
#  (78.291018, 'Skydance Productions', 54138),
#  (78.291018, 'Bad Robot', 54138),
#  (78.291018, 'Kurtzman/Orci', 54138),
#  (78.144395, 'Warner Bros.', 675),
#  (78.144395, 'Heyday Films', 675),
#  (77.817571, 'Walt Disney Pictures', 9806),
#  (77.817571, 'Pixar Animation Studios', 9806),
#  (77.77477, 'Paramount Pictures', 56292),
#  (77.77477, 'Skydance Productions', 56292),
#  (77.77477, 'Bad Robot', 56292),
#  (77.77477, 'TC Productions', 56292),
#  (77.77477, 'Revolution Sun Studios', 56292),
#  (77.77477, 'Kontsept Film Company', 56292),
#  (77.68208, 'Marvel Studios', 68721),
#  (77.580661, 'Millennium Films', 27578),
#  (77.300194, 'Marvel Studios', 10138),
#  (77.178973, 'Universal Pictures', 58595),
#  (77.178973, 'Roth Films', 58595),
#  (76.842247, 'Paramount Pictures', 184315),
#  (76.842247, 'Metro-Goldwyn-Mayer (MGM)', 184315),
#  (76.842247, 'Radical Studios', 184315),
#  (76.842247, 'Flynn Picture Company', 184315),
#  (76.840712, 'Village Roadshow Pictures', 163),
#  (76.840712, 'Section Eight', 163),
#  (76.840712, 'Jerry Weintraub Productions', 163),
#  (76.840712, 'Warner Bros.', 163),
#  (76.840712, 'WV Films III', 163),
#  (76.603233, 'Universal Pictures', 105),
#  (76.603233, 'Amblin Entertainment', 105),
#  (76.603233, 'U-Drive Productions', 105),
#  (76.310119, 'Lionsgate', 101299),
#  (76.310119, 'Color Force', 101299),
#  (76.041867, 'Paramount Pictures', 857),
#  (76.041867, 'DreamWorks SKG', 857),
#  (76.041867, 'Amblin Entertainment', 857),
#  (76.041867, 'Mutual Film Company', 857),
#  (76.041867, 'Mark Gordon Productions', 857),
#  (75.674458, 'Lucasfilm', 217),
#  (75.674458, 'Paramount Pictures', 217),
#  (75.290998, 'Paramount Pictures', 954),
#  (75.290998, 'Cruise/Wagner Productions', 954),
#  (74.817641, 'Working Title Films', 122906),
#  (74.817641, 'Translux', 122906),
#  (74.64653, 'Vertigo Entertainment', 241554),
#  (74.64653, 'Energy Entertainment', 241554),
#  (74.64653, 'RatPac-Dune Entertainment', 241554),
#  (74.506246, 'Marvel Studios', 1771),
#  (74.440708, 'Warner Bros.', 1124),
#  (74.440708, 'Touchstone Pictures', 1124),
#  (74.440708, 'Syncopy', 1124),
#  (74.417456, 'Fox Searchlight Pictures', 120467),
#  (74.417456, 'Scott Rudin Productions', 120467),
#  (74.417456, 'Studio Babelsberg', 120467),
#  (74.417456, 'Indian Paintbrush', 120467),
#  (74.417456, 'TSG Entertainment', 120467),
#  (74.417456, 'American Empirical Pictures', 120467),
#  (74.358971, 'Fox 2000 Pictures', 222935),
#  (74.358971, 'Temple Hill Entertainment', 222935),
#  (74.358971, 'TSG Entertainment', 222935),
#  (74.234793, 'Orion Pictures', 218),
#  (74.234793, 'Pacific Western', 218),
#  (74.234793, 'Hemdale Film', 218),
#  (74.234793, 'Cinema 84', 218),
#  (74.234793, 'Euro Film Funding', 218),
#  (74.168016, 'Columbia Pictures', 228967),
#  (74.168016, 'Point Grey Pictures', 228967),
#  (73.987775, 'Lionsgate', 22970),
#  (73.987775, 'Mutant Enemy Productions', 22970),
#  (73.944049, 'Kemp Company', 640),
#  (73.944049, 'Splendid Pictures', 640),
#  (73.944049, 'Parkes/MacDonald Productions', 640),
#  (73.872343, 'Anarchos Productions', 83542),
#  (73.872343, 'X-Filme Creative Pool', 83542),
#  (73.872343, 'Ascension Pictures', 83542),
#  (73.872343, 'ARD Degeto Film', 83542),
#  (73.872343, 'Cloud Atlas Productions', 83542),
#  (73.872343, 'Five Drops', 83542),
#  (73.872343, 'Media Asia Group', 83542),
#  (73.872343, 'Dreams of Dragon Picture', 83542),
#  (73.82289, 'Universal Pictures', 8909),
#  (73.82289, 'Spyglass Entertainment', 8909),
#  (73.82289, 'Bazelevs Production', 8909),
#  (73.82289, 'Kickstart Productions', 8909),
#  (73.82289, 'Marc Platt Productions', 8909),
#  (73.82289, 'Top Cow Productions', 8909),
#  (73.82289, 'Relativity Media', 8909),
#  (73.82289, 'Ringerike Zweite Filmproduktion', 8909),
#  (73.82289, 'Revolution Sun Studios', 8909),
#  (73.79505, 'Walt Disney Pictures', 20526),
#  (73.79505, 'LivePlanet', 20526),
#  (73.79505, 'Prana Studios', 20526),
#  (73.79505, 'Sean Bailey Productions', 20526),
#  (73.79505, 'Revolution Sun Studios', 20526),
#  (73.79505, 'Kontsept Film Company', 20526),
#  (73.720244, 'France 3 CinTma', 194),
#  (73.720244, 'Claudie Ossard Productions', 194),
#  (73.720244, 'MMC Independent', 194),
#  (73.720244, 'Canal+', 194),
#  (73.720244, 'Tapioca Films', 194),
#  (73.720244, 'Sofica Sofinergie 5', 194),
#  (73.720244, 'Victoires Productions', 194),
#  (73.720244, 'Filmstiftung Nordrhein-Westfalen', 194),
#  (73.720244, 'Union GTnTrale CinTmatographique (UGC)', 194),
#  (73.640445, 'Pixar Animation Studios', 862),
#  (73.616808, 'Paramount Pictures', 13475),
#  (73.616808, 'Spyglass Entertainment', 13475),
#  (73.616808, 'Bad Robot', 13475),
#  (73.616808, 'MavroCine Pictures GmbH & Co. KG', 13475),
#  (73.575118, 'Pixar Animation Studios', 863),
#  (73.567232, 'New Line Cinema', 73),
#  (73.567232, 'The Turman-Morrissey Company', 73),
#  (73.567232, 'Savoy Pictures', 73),
#  (73.313918, 'Village Roadshow Pictures', 605),
#  (73.313918, 'NPV Entertainment', 605),
#  (73.313918, 'Silver Pictures', 605),
#  (73.313918, 'Warner Bros.', 605),
#  (73.307513, 'New Line Cinema', 1954),
#  (73.307513, 'FilmEngine', 1954),
#  (73.307513, 'Katalyst Films', 1954),
#  (73.307513, 'BenderSpink', 1954),
#  (73.307513, 'Province of British Columbia Production Services Tax Credit', 1954),
#  (73.085576, 'Spyglass Entertainment', 745),
#  (73.085576, 'The Kennedy/Marshall Company', 745),
#  (73.085576, 'Hollywood Pictures', 745),
#  (73.085576, 'Barry Mendel Productions', 745),
#  (72.774941, 'Universal Pictures', 271718),
#  (72.774941, 'Fuji Television Network', 271718),
#  (72.774941, 'Dentsu', 271718),
#  (72.774941, 'Apatow Productions', 271718),
#  (72.641296, 'Escape Artists', 225886),
#  (72.641296, 'Media Rights Capital', 225886),
#  (72.641296, 'Sony Pictures Entertainment (SPE)', 225886),
#  (72.641296, 'LStar Capital', 225886),
#  (72.595961, 'Universal Pictures', 16869),
#  (72.595961, 'A Band Apart', 16869),
#  (72.595961, 'The Weinstein Company', 16869),
#  (72.595961, 'Zehnte Babelsberg', 16869),
#  (72.595961, 'Visiona Romantica', 16869),
#  (72.225265, 'Marvel Studios', 100402),
#  (72.19808, 'United Artists', 1366),
#  (71.862892, 'Columbia Pictures', 534),
#  (71.862892, 'The Halcyon Company', 534),
#  (71.862892, 'Wonderland Sound and Vision', 534),
#  (71.862892, 'Warner Bros.', 534),
#  (71.510596, 'Legendary Pictures', 53182),
#  (71.510596, 'Hollywood Gang Productions', 53182),
#  (71.510596, 'Atmosphere Entertainment MM', 53182),
#  (71.510596, 'Warner Bros.', 53182),
#  (71.510596, 'Nimar Studios', 53182),
#  (71.510596, 'Cruel and Unusual Films', 53182),
#  (71.496894, 'Universal Pictures', 254470),
#  (71.496894, 'Gold Circle Films', 254470),
#  (71.496894, 'Brownstone Productions', 254470),
#  (71.124686, 'Summit Entertainment', 75656),
#  (71.124686, 'K/O Paper Products', 75656),
#  (71.124686, 'SOIXAN7E QUIN5E', 75656),
#  (71.124686, 'See Me Louisiana', 75656),
#  (70.867401, 'Village Roadshow Pictures', 6479),
#  (70.867401, 'Original Film', 6479),
#  (70.867401, 'Weed Road Pictures', 6479),
#  (70.867401, 'Warner Bros.', 6479),
#  (70.867401, 'Heyday Films', 6479),
#  (70.867401, 'Overbrook Entertainment', 6479),
#  (70.78591, 'Village Roadshow Pictures', 604),
#  (70.78591, 'NPV Entertainment', 604),
#  (70.78591, 'Heineken Branded Entertainment', 604),
#  (70.78591, 'Silver Pictures', 604),
#  (70.78591, 'Warner Bros.', 604),
#  (70.668923, 'Twentieth Century Fox Film Corporation', 193893),
#  (70.668923, 'WideAwake', 193893),
#  (70.668923, 'Genre Films', 193893),
#  (70.456012, 'Lakeshore Entertainment', 70),
#  (70.456012, 'Malpaso Productions', 70),
#  (70.456012, 'Epsilon Motion Pictures', 70),
#  (70.456012, 'Warner Bros.', 70),
#  (70.456012, 'Albert S. Ruddy Productions', 70),
#  (70.398356, 'Columbia Pictures', 782),
#  (70.398356, 'Jersey Films', 782),
#  (70.105981, 'Universal Pictures', 111),
#  (69.457898, 'Blue Sky Studios', 8355),
#  (69.457898, 'Twentieth Century Fox Animation', 8355),
#  (69.405188, 'Columbia Pictures', 296),
#  (69.405188, 'Intermedia Films', 296),
#  (69.405188, 'Warner Bros.', 296),
#  (69.405188, 'C-2 Pictures', 296),
#  (69.405188, 'IMF Internationale Medien und Film GmbH & Co. 3. Produktions KG', 296),
#  (69.405188, 'Mostow/Lieberman Productions', 296),
#  (69.27822, 'Columbia Pictures', 37799),
#  (69.27822, 'Scott Rudin Productions', 37799),
#  (69.27822, 'Relativity Media', 37799),
#  (68.889395, 'Twentieth Century Fox Film Corporation', 70981),
#  (68.889395, 'Dune Entertainment', 70981),
#  (68.889395, 'Scott Free Productions', 70981),
#  (68.889395, 'Brandywine Productions', 70981),
#  (68.87691, 'Universal Pictures', 72105),
#  (68.87691, 'Media Rights Capital', 72105),
#  (68.87691, 'Fuzzy Door Productions', 72105),
#  (68.794673, 'New Line Cinema', 259693),
#  (68.794673, 'Dune Entertainment', 259693),
#  (68.794673, 'The Safran Company', 259693),
#  (68.794673, 'Evergreen Media Group', 259693),
#  (68.794673, 'warner bross Turkey', 259693),
#  (68.794673, 'Soho VFX', 259693),
#  (68.794673, 'Atomic Monster', 259693),
#  (68.757242, 'DreamWorks Animation', 38055),
#  (68.734513, 'Universal Pictures', 214756),
#  (68.734513, 'Fuzzy Door Productions', 214756),
#  (68.734513, 'Bluegrass Films', 214756),
#  (68.734513, 'Smart Entertainment', 214756),
#  (68.734513, 'Media Rights Capital (MRC)', 214756),
#  (68.717016, 'Double Feature Films', 273248),
#  (68.717016, 'The Weinstein Company', 273248),
#  (68.717016, 'FilmColony', 273248),
#  (68.550698, 'Lionsgate', 70160),
#  (68.550698, 'Color Force', 70160),
#  (68.159596, 'Lucasfilm', 85),
#  (68.159596, 'Paramount Pictures', 85),
#  (68.140214, 'Imagine Entertainment', 568),
#  (68.140214, 'Universal Pictures', 568),
#  (67.767785, 'New Line Cinema', 100042),
#  (67.767785, 'Universal Pictures', 100042),
#  (67.767785, 'Conundrum Entertainment', 100042),
#  (67.767785, 'Red Granite Pictures', 100042),
#  (67.698004, 'Universal Pictures', 75612),
#  (67.698004, 'Chernin Entertainment', 75612),
#  (67.698004, 'Relativity Media', 75612),
#  (67.698004, 'Monolith Pictures (III)', 75612),
#  (67.698004, 'Radical Studios', 75612),
#  (67.66094, 'Twentieth Century Fox Film Corporation', 679),
#  (67.66094, 'SLM Production Group', 679),
#  (67.66094, 'Brandywine Productions', 679),
#  (67.608041, 'Paramount Pictures', 621),
#  (67.608041, 'Robert Stigwood Organization (RSO)', 621),
#  (67.447636, 'Columbia Pictures', 13448),
#  (67.447636, 'Imagine Entertainment', 13448),
#  (67.447636, 'Panorama Films', 13448),
#  (67.447636, 'Skylark Productions', 13448),
#  (67.427755, 'Walt Disney Pictures', 10674),
#  (67.427755, 'Walt Disney Feature Animation', 10674),
#  (67.417542, "Loew's Incorporated", 630),
#  (67.391328, 'Walt Disney', 411),
#  (67.391328, 'Walden Media', 411),
#  (67.33767, 'TriStar Pictures', 68724),
#  (67.33767, 'Media Rights Capital', 68724),
#  (67.33767, 'Sony Pictures Entertainment (SPE)', 68724),
#  (67.33767, 'QED International', 68724),
#  (67.33767, 'Alpha Core', 68724),
#  (67.33767, 'Genre Films', 68724),
#  (67.33767, 'Simon Kinberg Productions', 68724),
#  (67.298732, 'DreamWorks SKG', 808),
#  (67.298732, 'Pacific Data Images (PDI)', 808),
#  (67.298732, 'DreamWorks Animation', 808),
#  (67.263269, 'DreamWorks Animation', 10191),
#  (67.263269, 'Vertigo Entertainment', 10191),
#  (67.263269, 'Mad Hatter Entertainment', 10191),
#  (67.169587, 'New Line Cinema', 36586),
#  (67.169587, 'Amen Ra Films', 36586),
#  (67.169587, 'Milk & Honey', 36586),
#  (67.169587, 'Imaginary Forces', 36586),
#  (67.169587, 'Justin Pictures', 36586),
#  (67.169587, 'Linovo Productions GmbH & Co. KG', 36586),
#  (67.169587, 'Pacific Title and Art Studio', 36586),
#  (67.169587, 'Marvel Enterprises', 36586),
#  (66.976776, 'Lucasfilm', 87),
#  (66.976776, 'Paramount Pictures', 87),
#  (66.925866, 'Live Entertainment', 500),
#  (66.925866, 'Lionsgate', 500),
#  (66.925866, 'Dog Eat Dog Productions Inc.', 500),
#  (66.803149, 'Plan B Entertainment', 652),
#  (66.803149, 'Warner Bros.', 652),
#  (66.803149, 'Nimar Studios', 652),
#  (66.803149, 'Radiant Productions', 652),
#  (66.803149, 'Helena Productions', 652),
#  (66.803149, 'Latina Pictures', 652),
#  (66.757869, 'Columbia Pictures', 97020),
#  (66.757869, 'Strike Entertainment', 97020),
#  (66.757869, 'Metro-Goldwyn-Mayer (MGM)', 97020),
#  (66.390712, 'Walt Disney Pictures', 10681),
#  (66.390712, 'Pixar Animation Studios', 10681),
#  (66.390712, 'FortyFour Studios', 10681),
#  (66.242737, 'Columbia Pictures', 223702),
#  (66.242737, 'Sony Pictures Animation', 223702),
#  (66.242737, 'Sony Pictures Entertainment', 223702),
#  (66.242737, 'Annapurna Pictures', 223702),
#  (66.242737, 'Point Grey Pictures', 223702),
#  (66.242737, 'Nitrogen Studios Canada', 223702),
#  (66.21806, 'Columbia Pictures', 43074),
#  (66.21806, 'Village Roadshow Pictures', 43074),
#  (66.21806, 'Montecito Picture Company, The', 43074),
#  (66.21806, 'LStar Capital', 43074),
#  (66.21806, 'Feigco Entertainment', 43074),
#  (66.21806, 'Pascal Pictures', 43074),
#  (66.21806, 'Ghostcorps', 43074),
#  (66.169628, 'Twentieth Century Fox Film Corporation', 562),
#  (66.169628, 'Gordon Company', 562),
#  (66.169628, 'Silver Pictures', 562),
#  (66.11334, 'TTlTfilm Canada', 264644),
#  (66.11334, 'Film 4', 264644),
#  (66.11334, 'Element Pictures', 264644),
#  (66.11334, 'Irish Film Board', 264644),
#  (66.11334, 'FilmNation Entertainment', 264644),
#  (66.11334, 'No Trace Camping', 264644),
#  (66.11334, 'A24', 264644),
#  (66.11334, 'Elevation Pictures', 264644),
#  (66.097437, 'Endgame Entertainment', 238615),
#  (66.097437, 'Ram Bergman Productions', 238615),
#  (66.003433, 'Dimension Films', 187),
#  (66.003433, 'Troublemaker Studios', 187),
#  (66.003433, 'Miramax', 187),
#  (65.948959, 'DreamWorks SKG', 180),
#  (65.948959, 'Cruise/Wagner Productions', 180),
#  (65.948959, 'Amblin Entertainment', 180),
#  (65.948959, 'Twentieth Century Fox Film Corporation', 180),
#  (65.948959, 'Blue Tulip Productions', 180),
#  (65.948959, 'Ronald Shusett/Gary Goldman', 180),
#  (65.948959, 'Digital Image Associates', 180),
#  (65.90161, 'Walt Disney Pictures', 224141),
#  (65.90161, 'Marc Platt Productions', 224141),
#  (65.90161, 'Lucamar Productions', 224141),
#  (65.677399, 'Walt Disney Pictures', 2062),
#  (65.677399, 'Pixar Animation Studios', 2062),
#  (65.402595, 'Ingenious Media', 47964),
#  (65.402595, 'Twentieth Century Fox Film Corporation', 47964),
#  (65.402595, 'Dune Entertainment', 47964),
#  (65.402595, 'Mid Atlantic Films', 47964),
#  (65.402595, 'Big Screen Productions', 47964),
#  (65.402595, 'Temple Hill Entertainment', 47964),
#  (65.402595, 'TSG Entertainment', 47964),
#  (65.402595, 'Giant Pictures', 47964),
#  (65.402595, 'Origo Film Group', 47964),
#  (65.364452, 'Escape Artists', 307081),
#  (65.364452, 'Riche-Ludwig Productions', 307081),
#  (65.352913, 'Paramount Pictures', 188927),
#  (65.352913, 'Bad Robot', 188927),
#  (65.352913, 'Perfect Storm Entertainment', 188927),
#  (65.352913, 'Alibaba Pictures Group', 188927),
#  (65.352913, 'Skydance Media', 188927),
#  (65.352913, 'Sneaky Shark', 188927),
#  (65.352913, 'Huahua Media', 188927),
#  (65.229868, 'Blue Sky Studios', 57800),
#  (65.229868, 'Twentieth Century Fox Animation', 57800),
#  (65.197968, 'Virtual Studios', 1271),
#  (65.197968, 'Legendary Pictures', 1271),
#  (65.197968, 'Hollywood Gang Productions', 1271),
#  (65.197968, 'Atmosphere Entertainment MM', 1271),
#  (65.197968, 'Warner Bros.', 1271),
#  (65.197968, 'Nimar Studios', 1271),
#  (65.197968, 'Cruel and Unusual Films', 1271),
#  (64.928382, 'Universal Pictures', 44833),
#  (64.928382, 'Hasbro', 44833),
#  (64.928382, 'Bluegrass Films', 44833),
#  (64.928382, 'Film 44', 44833),
#  (64.798873, 'Paramount Pictures', 13183),
#  (64.798873, 'DC Comics', 13183),
#  (64.798873, 'Lawrence Gordon Productions', 13183),
#  (64.798873, 'Legendary Pictures', 13183),
#  (64.798873, 'Warner Bros.', 13183),
#  (64.798873, 'Cruel and Unusual Films', 13183),
#  (64.782984, 'Python (Monty) Pictures Limited', 762),
#  (64.782984, 'Michael White Productions', 762),
#  (64.782984, 'National Film Trustee Company', 762),
#  (64.782984, 'Twickenham Film Studios', 762),
#  (64.610671, 'Fox 2000 Pictures', 286565),
#  (64.504747, 'Twentieth Century Fox Film Corporation', 76726),
#  (64.504747, 'Dune Entertainment', 76726),
#  (64.504747, 'Davis Entertainment', 76726),
#  (64.504747, 'Adam Schroeder Productions', 76726),
#  (64.457947, 'Universal Pictures', 49017),
#  (64.457947, 'Legendary Pictures', 49017),
#  (64.457947, 'Fuji Television Network', 49017),
#  (64.457947, 'Dentsu', 49017),
#  ...]

# %% [markdown]
# **Question 10**
#
# How many female actors (i.e. gender = 1) have a name that starts with the letter "N"?
#
#
# **Options:**
#
#  - 0
#  - 355
#  - 7335
#  - 1949

# %%
# %%sql
#
# SELECT COUNT(*)
# FROM actors
# WHERE actor_name LIKE 'N%'
# AND gender = 1;
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(355,)]

# %% [markdown]
# **Question 11**
#
# Which genre has, on average, the lowest movie popularity score?
#
#
# **Options:**
#
#  - Science Fiction
#  - Animation
#  - Documentary
#  - Foreign

# %%
# %%sql
# Out:
# UsageError: %%sql is a cell magic, but the cell body is empty. Did you mean the line magic %sql (single %)?

# %% [markdown]
# **Question 12**
#
# Which award category has the highest number of actor nominations (actors can be male or female)? (Hint `Oscars.name` contains both actors names and film names)
#
# **Options:**
#
# - Special Achievement Award
# - Actor in a Supporting Role
# - Actress in a Supporting Role
# - Best Picture

# %%
# %%sql
#
# SELECT COUNT(award), award, name
# FROM oscars
# GROUP BY award
# ORDER BY COUNT(award) DESC;
# Out:
#  * sqlite:///TMDB.db
# Done.
# [(429, 'Directing', 'Lionel Barrymore'),
#  (410, 'Film Editing', 'Cleopatra '),
#  (400, 'Actress in a Supporting Role', 'Beulah Bondi'),
#  (400, 'Actor in a Supporting Role', 'Mischa Auer'),
#  (348, 'Documentary (Short Subject)', 'Adventure in the Bronx '),
#  (315, 'Documentary (Feature)', 'Baptism of Fire '),
#  (307, 'Art Direction', 'Rochus Gliese'),
#  (300, 'Foreign Language Film', 'The Captain of Kopenick '),
#  (298, 'Cinematography', 'George Barnes'),
#  (298, 'Best Picture', 'Lawrence of Arabia '),
#  (255, 'Costume Design', 'An Affair to Remember '),
#  (236, 'Actress', 'Louise Dresser'),
#  (232, 'Actor', 'Richard Barthelmess'),
#  (230, 'Music (Original Score)', 'The Adventures of Robin Hood '),
#  (225, 'Sound', 'I Want to Live! '),
#  (215, 'Music (Song)', '"""Carioca"" from Flying Down to Rio"'),
#  (200, 'Actress in a Leading Role', 'Marie-Christine Barrault'),
#  (200, 'Actor in a Leading Role', 'Robert De Niro'),
#  (195, 'Sound Recording', 'The Big House '),
#  (195, 'Music (Original Song)', '"""How Lucky Can You Get"" from Funny Lady"'),
#  (186, 'Short Film (Live Action)', 'Climb '),
#  (175, 'Short Film (Animated)', 'Closed Mondays '),
#  (169, 'Short Subject (Cartoon)', 'Flowers and Trees '),
#  (161, 'Cinematography (Black and White)', 'First Love '),
#  (148, 'Music (Music Score of a Dramatic or Comedy Picture)', 'Arabian Nights '),
#  (138, 'Art Direction (Black and White)', 'Arise, My Love '),
#  (135, 'Cinematography (Color)', 'Drums along the Mohawk '),
#  (127, 'Music (Scoring of a Musical Picture)', 'All-American Co-Ed '),
#  (120, 'Writing (Screenplay Written Directly for the Screen)', 'Autumn Sonata '),
#  (120, 'Writing (Original Screenplay)', 'Angels over Broadway '),
#  (115, 'Visual Effects', 'Close Encounters of the Third Kind '),
#  (112, 'Art Direction (Color)', 'Bitter Sweet '),
#  (110, 'Honorary Award', 'George Murphy'),
#  (104, 'Writing (Screenplay)', 'Captain Blood '),
#  (102, 'Outstanding Production', 'All Quiet on the Western Front '),
#  (95, 'Writing (Screenplay, Based on Material from Another Medium)', 'The Bridge on the River Kwai '),
#  (93, 'Special Effects', 'Gone with the Wind '),
#  (90, 'Short Subject (One Reel)', 'Bored of Education '),
#  (90, 'Best Motion Picture', 'Double Indemnity '),
#  (87, 'Makeup', 'An American Werewolf in London '),
#  (81, 'Short Subject (Two Reel)', 'Double or Nothing '),
#  (77, 'Costume Design (Color)', 'The Emperor Waltz '),
#  (77, 'Costume Design (Black and White)', "B. F.'s Daughter "),
#  (70, 'Writing (Adapted Screenplay)', 'About a Boy '),
#  (68, 'Short Subject (Live Action)', 'A Chairy Tale '),
#  (66, 'Sound Editing', 'Space Cowboys '),
#  (65, 'Writing (Screenplay Based on Material from Another Medium)', 'Bloodbrothers '),
#  (65, 'Sound Mixing', 'The Last Samurai '),
#  (64, 'Music (Scoring)', 'The Gay Divorcee '),
#  (60, 'Writing (Story and Screenplay, Written Directly for the Screen)', 'Designing Woman '),
#  (59, 'Animated Feature Film', 'Jimmy Neutron: Boy Genius '),
#  (55, 'Writing (Screenplay Based on Material Previously Produced or Published)', 'Europa Europa '),
#  (55, 'Special Award', 'Warner Brothers'),
#  (52, 'Writing (Original Story)', 'Lajos Biro'),
#  (50, 'Writing (Motion Picture Story)', 'A Cage of Nightingales '),
#  (47, 'Sound Effects Editing', 'Das Boot '),
#  (44, 'Irving G. Thalberg Memorial Award', 'Darryl F. Zanuck'),
#  (41, 'Music (Original Dramatic Score)', 'Mary, Queen of Scots '),
#  (38, 'Jean Hersholt Humanitarian Award', 'Y. Frank Freeman'),
#  (35, 'Writing (Story and Screenplay)', 'Battleground '),
#  (35, 'Assistant Director', 'Percy Ikerd (Fox)'),
#  (30, 'Outstanding Motion Picture', 'Blossoms in the Dust '),
#  (30, 'Music (Scoring of Music, Adaptation or Treatment)', "Billy Rose's Jumbo "),
#  (25, 'Writing (Original Motion Picture Story)', 'Holiday Inn '),
#  (25, 'Music (Song, Original for the Picture)', '"""Chitty Chitty Bang Bang"" from Chitty Chitty Bang Bang"'),
#  (25, 'Gordon E. Sawyer Award', 'Joseph B. Walker'),
#  (25, 'Documentary', 'Africa, Prelude to Victory '),
#  (22, 'Dance Direction', 'Busby Berkeley'),
#  (20, 'Writing (Story and Screenplay, Based on Factual Material or Material Not Previously Published or Produced)', 'Five Easy Pieces '),
#  (20, 'Production Design', 'Anna Karenina '),
#  (20, 'Music (Original Musical or Comedy Score)', 'The American President '),
#  (20, 'Music (Music Score, Substantially Original)', 'Freud '),
#  (20, 'Music (Music Score of a Dramatic Picture)', 'All That Money Can Buy '),
#  (19, 'John A. Bonner Medal of Commendation', 'Volker W. Bahnemann'),
#  (18, 'Medal of Commendation', 'Gordon E. Sawyer'),
#  (17, 'Writing (Adaptation)', 'Alfred Cohn'),
#  (16, 'Special Visual Effects', 'Mary Poppins '),
#  (13, 'Short Subject (Comedy)', 'The Loud Mouth '),
#  (12, 'Short Subject (Novelty)', 'Screen Souvenirs '),
#  (12, 'Makeup and Hairstyling', 'Hitchcock '),
#  (12, 'Award of Commendation', "The Academy of Motion Picture Arts and Sciences' Board of Governors"),
#  (11, 'Writing', 'Tom Barry'),
#  (10, 'Writing (Screenplay Written Directly for the Screen, Based on Factual Material or on Story Material Not Previously Published or Produced)', 'Cousin, Cousine '),
#  (10, 'Writing (Screenplay Adapted from Other Material)', 'The Apprenticeship of Duddy Kravitz '),
#  (10, 'Sound Effects', 'A Gathering of Eagles '),
#  (10, 'Music (Score of a Musical Picture, Original or Adaptation)', "Finian's Rainbow "),
#  (10, 'Music (Original Score, for a Motion Picture [Not a Musical])', 'The Fox '),
#  (10, 'Music (Original Music Score)', 'The Bible '),
#  (9, 'Special Achievement Award (Visual Effects)', 'The Poseidon Adventure '),
#  (9, 'Short Subject (Animated)', 'The Crunch Bird '),
#  (9, 'Music (Scoring: Original Song Score and Adaptation -Or- Scoring: Adaptation)', 'Jesus Christ Superstar '),
#  (8, 'Outstanding Picture', 'The Caddo Company'),
#  (8, 'Music (Scoring: Adaptation and Original Song Score)', 'Bedknobs and Broomsticks '),
#  (8, 'Music (Original Song Score)', 'The Baby Maker '),
#  (6, 'Short Subject (Color)', 'Give Me Liberty '),
#  (6, 'Music (Original Song Score and Its Adaptation or Adaptation Score)', 'Bound for Glory '),
#  (6, 'Music (Original Song Score and Its Adaptation -Or- Adaptation Score)', 'All That Jazz '),
#  (5, 'Writing (Story and Screenplay, Based on Material Not Previously Published or Produced)', 'Bob & Carol & Ted & Alice '),
#  (5, 'Writing (Screenplay, Original)', 'The Bold and the Brave '),
#  (5, 'Writing (Screenplay, Adapted)', 'Around the World in 80 Days '),
#  (5, 'Honorary Foreign Language Film Award', 'The Walls of Malapaga'),
#  (4, 'Special Achievement Award (Sound Effects Editing)', 'Close Encounters of the Third Kind '),
#  (3, 'Writing (Title Writing)', 'Gerald Duffy'),
#  (3, 'Unique and Artistic Picture', 'Fox'),
#  (3, 'Special Achievement Award', 'Benjamin Burtt, Jr.'),
#  (3, 'Short Film (Dramatic Live Action)', 'The Dollar Bottom '),
#  (3, 'Music (Original Song Score or Adaptation Score)', 'The Sting II '),
#  (3, 'Music (Adaptation Score)', 'The Buddy Holly Story '),
#  (3, 'Engineering Effects', 'Ralph Hammeras'),
#  (3, 'Directing (Dramatic Picture)', 'Frank Borzage'),
#  (2, 'Special Foreign Language Film Award', 'Monsieur Vincent'),
#  (2, 'Directing (Comedy Picture)', 'Lewis Milestone'),
#  (1, 'Special Achievement Award (Sound Effects)', 'The Hindenburg '),
#  (1, 'Special Achievement Award (Sound Editing)', 'The Black Stallion ')]

# %% [markdown]
# **Question 13**
#
# For all of the entries in the Oscars table before 1934, the year is stored differently than in all the subsequent years. E.g the year would be saved as “1932/1933” instead of just “1933” (the second indicated year).  Which of the following options would be the appropriate code to update this column to have the format of the year be consistent throughout the entire table (second indicated year only shown)?
#
#
# **Options:**
#
# - `UPDATE Oscars SET year = RIGHT(year, -4)`
# - `UPDATE Oscars SET year = SELECT substr(year, -4)`
# - `UPDATE Oscars SET year = substr(year, -4)`
# - `UPDATE Oscars year =  substr(year, 4)`

# %%
# %%sql
#
# UPDATE Oscars
# SET year = substr(year, -4);
# Out:
#  * sqlite:///TMDB.db
# 9964 rows affected.
# []

# %% [markdown]
# **Question 14**
#
# DStv will be having a special week dedicated to the actor Alan Rickman. Which of the following queries would create a new _view_ that shows the titles, release dates, taglines, and overviews of all movies that Alan Rickman has played in?
#
#
#
# **Options:**
#
# - SELECT title, release_date, tagline, overview
# FROM Movies LEFT JOIN Casts ON Casts.movie_id = Movies.movie_id Left JOIN Actors ON Casts.actor_id = Actors.actor_id
# WHERE Actors.actor_name = 'Alan Rickman'
# AS VIEW Alan_Rickman_Movies
#
# - CREATE VIEW Alan_Rickman_Movies AS
# SELECT title, release_date, tagline, overview FROM Movies
# LEFT JOIN Casts ON Casts.movie_id = Movies.movie_id Left JOIN Actors
# ON Casts.actor_id = Actors.actor_id
# WHERE Actors.actor_name = 'Alan Rickman'
#
#
# - CREATE NEW VIEW  Name  = Alan_Rickman_Movies AS SELECT title, release_date, tagline, overview FROM Movies LEFT JOIN Casts ON Casts.movie_id = Movies.movie_id Left JOIN Actors ON Casts.actor_id = Actors.actor_id WHERE Actors.actor_name = 'Alan Rickman'
#
# - VIEW Alan_Rickman_Movies AS SELECT title, release_date, tagline, overview FROM Movies LEFT JOIN Casts ON Casts.movie_id = Movies.movie_id Left JOIN Actors ON Casts.actor_id = Actors.actor_id WHERE Actors.actor_name = 'Alan Rickman'

# %%
# %%sql
#
# CREATE VIEW Alan_Rickman_Movies AS
# SELECT title, release_date, tagline, overview
# FROM Movies
# LEFT JOIN Casts
# ON Casts.movie_id = Movies.movie_id
# LEFT JOIN Actors
# ON Casts.actor_id = Actors.actor_id
# WHERE Actors.actor_name = 'Alan Rickman';
# Out:
#  * sqlite:///TMDB.db
# Done.
# []

# %% [markdown]
# **Question 15**
#
# Which of the statements about database normalisation is true?
#
# **Statements:**
#
# i) Database normalisation improves data redundancy, saves on storage space and fulfills the requirement of records to be uniquely identified.
#
# ii) Database normalisation supports up to 3rd normal form and removes all data anomalies.
#
# iii) Database normalisation removes inconsistencies which may cause the analysis of our data to be more complicated.
#
# iv) Database normalisation causes data redundancy, increases storage space and creates duplicate records.
#
# **Options:**
#
#  - (i), (ii)
#  - (i), (iii)
#  - (ii), (iv)
#  - (iii), (iv)
